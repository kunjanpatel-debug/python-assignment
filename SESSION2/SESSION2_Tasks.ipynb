# %%
#TASK 1: Basic Variable Assignment

user_name = "Kunjan Patel"
fav_app = "Zomato"
daily_usage_hours = 1.5

print("User Name:", user_name)
print("Favorite App:", fav_app)
print("Daily Usage (Hours):", daily_usage_hours)
# Out:
# User Name: Kunjan Patel
# Favorite App: Zomato
# Daily Usage (Hours): 1.5

# %%
# TASK 2: Flipkart E-Commerce Item Data Types

product_name = "Wireless Keyboard"
price = 2499.00
is_available = True

print("Product:", product_name, "| Type:", type(product_name))
print("Price: ₹", price, "| Type:", type(price))
print("Available:", is_available, "| Type:", type(is_available))
# Out:
# Product: Wireless Keyboard | Type: <class 'str'>
# Price: ₹ 2499.0 | Type: <class 'float'>
# Available: True | Type: <class 'bool'>

# %%
# TASK 3: Spotify Recommendation System Logic

#Multi-line Comment (Triple Quotes):
#How the Spotify recommendation engine processes music pipelines:
#1. Collaborative Filtering: Matches metrics against users with similar listening trends.
#2. Content-Based Filtering: Analyzes acoustic features like tempo, energy, and key signatures.
#3. Natural Language Processing: Scours web articles, reviews, and metadata for tracking music trends.


# Single-line comment: Defining target audio profile variables for analysis

user_top_genre = "Lo-Fi"  # Tracks user's primary genre streaming affinity
tracks_skipped = 2       # Tracks skip frequency to down-rank bad recommendation hits

print(f"Analyzing recommendation queue for sound profiles matching: {user_top_genre}")
# Out:
# Analyzing recommendation queue for sound profiles matching: Lo-Fi

# %%
#TASK 4: Zomato Order Formatting

order_total = 450.50
delivery_region = "Alkapuri, Vadodara"
discount_percent = 15

print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order from Alkapuri, Vadodara totals ₹450.5 with 15% discount.

# %%
#TASK 5: Resolving Indentation Formatting Mismatches

def calculate_loyalty_points(orders_count):
    base_points = 10
    total_points = orders_count * base_points
    return total_points

print("Calculated Loyalty Points:", calculate_loyalty_points(5))
# Out:
# Calculated Loyalty Points: 50
