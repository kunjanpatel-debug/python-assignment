# %%
#TASK 1: Product and Electronics Discount

class Product:
    def get_discount(self):
        return 0

class Electronics(Product):
    def get_discount(self):
        return 10

generic_item = Product()
tech_item = Electronics()

print("Product Discount:", generic_item.get_discount(), "%")
print("Electronics Discount:", tech_item.get_discount(), "%")
# Out:
# Product Discount: 0 %
# Electronics Discount: 10 %

# %%
#TASK 2: FoodOrder and ZomatoOrder Delivery Fee

class FoodOrder:
    def __init__(self, base_price):
        self.base_price = base_price

    def calculate_total(self):
        return self.base_price

class ZomatoOrder(FoodOrder):
    def calculate_total(self):
        delivery_charge = self.base_price * 0.05
        return self.base_price + delivery_charge

standard_order = FoodOrder(400)
zomato_order = ZomatoOrder(400)

print("Standard Order Total: ₹", standard_order.calculate_total())
print("Zomato Order Total (with 5% delivery): ₹", zomato_order.calculate_total())
# Out:
# Standard Order Total: ₹ 400
# Zomato Order Total (with 5% delivery): ₹ 420.0

# %%
# TASK 3: Polymorphism with show_bonus Function

class Influencer:
    def bonus(self):
        return 2000

class BrandManager:
    def bonus(self):
        return 5000

def show_bonus(employee):
    print("Bonus amount: ₹", employee.bonus())

creator = Influencer()
manager = BrandManager()

show_bonus(creator)
show_bonus(manager)
# Out:
# Bonus amount: ₹ 2000
# Bonus amount: ₹ 5000

# %%
#TASK 4: User and PremiumUser Status Overriding

class User:
    def get_status(self):
        return 'active'

class PremiumUser(User):
    def get_status(self):
        return 'premium'

normal_user = User()
vip_user = PremiumUser()

print("Normal User Status:", normal_user.get_status())
print("Premium User Status:", vip_user.get_status())
# Out:
# Normal User Status: active
# Premium User Status: premium
